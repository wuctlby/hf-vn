# %%
import uproot
import pandas as pd
import matplotlib.pyplot as plt
import awkward as ak

tables_correlator = [
    "O2hfcredsechhad",
    "O2hfcredmechhad",
    "O2hfcredsehadhad",
    "O2hfcredmehadhad",
    "O2hfcredcollinfo"
]

tables_data_creator = [
    "O2hfcredcorrcoll",
    "O2hfcredsechbase",
    "O2hfcredsehadbase",
    "O2hfcredassbase",
    "O2hfcredasstrack",
    "O2hfcredtrigbase",
    "O2hfcredtrigcharm",
    "O2hfcredtrigtrack",
]

tables = tables_correlator

with uproot.open("AO2D.root") as f:
    keys = f.keys()
    print("ROOT Keys:", keys)
    
    for table in tables:
        # Filter keys that match the table name
        matched_keys = [key for key in keys if table in key]
        
        if not matched_keys:
            print(f"No keys found for table: {table}")
            continue
        
        dfs = []
        for key in matched_keys:
            print(f"Reading {key}")
            array = f[key].arrays(library="ak")  # get awkward array
            df = ak.to_dataframe(array)          # convert to pandas DataFrame
            dfs.append(df)
        
        full_df = pd.concat(dfs, ignore_index=True)
        print(f"\nTable: {table}")
        print(f"Number of entries: {len(full_df)}")
        print(f"Columns: {full_df.columns.tolist()}")
        if (len(full_df) == 0):
            print(f"No data in table: {table}, skipping plotting.")
            continue

        # Plotting
        n_columns = len(full_df.columns)
        n_rows = (n_columns // 4) + (1 if n_columns % 4 else 0)
        
        fig, axes = plt.subplots(n_rows, 4, figsize=(15, 5 * n_rows))
        axes = axes.flatten()

        for i, column in enumerate(full_df.columns):
            print(f"Plotting {column}")
            try:
                axes[i].hist(full_df[column].dropna(), bins=50, color='blue')
                axes[i].set_title(f'{column}')
                axes[i].set_xlabel('Value')
                axes[i].set_ylabel('Frequency')
                # axes[i].set_yscale('log')
            except Exception as e:
                print(f"Could not plot column {column}: {e}")
                axes[i].set_visible(False)
        
        # Remove unused axes if any
        for i in range(n_columns, len(axes)):
            fig.delaxes(axes[i])
        
        fig.suptitle(f"Histograms for table: {table}", fontsize=16)
        plt.tight_layout(rect=[0, 0, 1, 0.96])
        plt.show()
# Out:
# ROOT Keys: ['DF_2424272990988224;1', 'DF_2424272990988224/O2hfcredcollinfo;1', 'DF_2424272990988224/O2hfcredmechhad;1', 'DF_2424272990988224/O2hfcredmehadhad;1', 'DF_2424272990988224/O2hfcredsechhad;1', 'DF_2424272990988224/O2hfcredsehadhad;1', 'parentFiles;1']
# Reading DF_2424272990988224/O2hfcredsechhad;1
#
# Table: O2hfcredsechhad
# Number of entries: 0
# Columns: ['fPoolBin', 'fPtTrig', 'fPtAssoc', 'fDeltaEta', 'fDeltaPhi', 'fInvMassTrig', 'fBdtScore0Trig', 'fBdtScore1Trig', 'fNTpcCrossedRowsAssoc', 'fItsClsMapAssoc', 'fItsNClsAssoc', 'fDcaXYAssoc', 'fDcaZAssoc']
# No data in table: O2hfcredsechhad, skipping plotting.
# Reading DF_2424272990988224/O2hfcredmechhad;1
#
# Table: O2hfcredmechhad
# Number of entries: 3104
# Columns: ['fPoolBin', 'fPtTrig', 'fPtAssoc', 'fDeltaEta', 'fDeltaPhi', 'fInvMassTrig', 'fBdtScore0Trig', 'fBdtScore1Trig', 'fNTpcCrossedRowsAssoc', 'fItsClsMapAssoc', 'fItsNClsAssoc', 'fDcaXYAssoc', 'fDcaZAssoc']
# Plotting fPoolBin
# Plotting fPtTrig
# Plotting fPtAssoc
# Plotting fDeltaEta
# Plotting fDeltaPhi
# Plotting fInvMassTrig
# Plotting fBdtScore0Trig
# Plotting fBdtScore1Trig
# Plotting fNTpcCrossedRowsAssoc
# Plotting fItsClsMapAssoc
# Plotting fItsNClsAssoc
# Plotting fDcaXYAssoc
# Plotting fDcaZAssoc
# Reading DF_2424272990988224/O2hfcredsehadhad;1
#
# Table: O2hfcredsehadhad
# Number of entries: 0
# Columns: ['fPoolBin', 'fPtTrig', 'fPtAssoc', 'fDeltaEta', 'fDeltaPhi', 'fNTpcCrossedRowsTrig', 'fItsClsMapTrig', 'fItsNClsTrig', 'fDcaXYTrig', 'fDcaZTrig', 'fNTpcCrossedRowsAssoc', 'fItsClsMapAssoc', 'fItsNClsAssoc', 'fDcaXYAssoc', 'fDcaZAssoc']
# No data in table: O2hfcredsehadhad, skipping plotting.
# Reading DF_2424272990988224/O2hfcredmehadhad;1
#
# Table: O2hfcredmehadhad
# Number of entries: 0
# Columns: ['fPoolBin', 'fPtTrig', 'fPtAssoc', 'fDeltaEta', 'fDeltaPhi', 'fNTpcCrossedRowsTrig', 'fItsClsMapTrig', 'fItsNClsTrig', 'fDcaXYTrig', 'fDcaZTrig', 'fNTpcCrossedRowsAssoc', 'fItsClsMapAssoc', 'fItsNClsAssoc', 'fDcaXYAssoc', 'fDcaZAssoc']
# No data in table: O2hfcredmehadhad, skipping plotting.
# Reading DF_2424272990988224/O2hfcredcollinfo;1
#
# Table: O2hfcredcollinfo
# Number of entries: 3104
# Columns: ['fMultiplicity', 'fNumPvContrib', 'fCentrality']
# Plotting fMultiplicity
# Plotting fNumPvContrib
# Plotting fCentrality
